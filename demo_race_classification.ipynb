# %% [markdown]
# <a href="https://colab.research.google.com/github/shambhavisrege/LitSurvey/blob/main/demo_race_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Copy the data to MyDrive: [Google Drive Folder](https://drive.google.com/drive/folders/1n929V9daji9IspX15vD97msUESHef5Qw?usp=sharing)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Downgrading the Python version, after running the cell go to runtime -> change runtime type -> py38

# %%
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py38" --user
# Out:
# --2023-10-03 19:45:44--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89817099 (86M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  85.66M   179MB/s    in 0.5s
#
# 2023-10-03 19:45:44 (179 MB/s) - ‘mini.sh’ saved [89817099/89817099]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/linux-64::libopenblas==0.3.20=pthreads_h78a6416_0
#   - defaults/linux-64::idna==2.8=py38_1000
#   - defaults/linux-64::conda==4.8.2=py38_0
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
# ...

# %%
import sys
print("User Current Version:-", sys.version)
# Out:
# User Current Version:- 3.8.18 (default, Sep 11 2023, 13:20:55)
# [GCC 11.2.0]

# %% [markdown]
# ##Installing Dependencies (Take long to install)

# %%
pip install dlib
# Out:
# ...
#   Using cached dlib-19.24.2.tar.gz (11.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for dlib: filename=dlib-19.24.2-cp38-cp38-linux_x86_64.whl size=4332880 sha256=1afc340006931d0867bf823ac119333c1251bdcf15e1256e2a4c4f6495bec71a
#   Stored in directory: /root/.cache/pip/wheels/21/03/71/98fd66c954809f33662e781bd02c4363cced2fa1c76178f812
# Successfully built dlib
# ...

# %%
# !pip install face_recognition
# Out:
# ...
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached Pillow-10.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.5 MB)
# Processing /root/.cache/pip/wheels/b4/4b/8f/751e99d45f089bdf366a7d3e5066db3c2b84a62e4377f534d7/face_recognition_models-0.3.0-py2.py3-none-any.whl
# ...
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# ...

# %%
pip install scikit_learn==0.22.2.post1
# Out:
# ...
#      |████████████████████████████████| 7.0 MB 11.7 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 302 kB 81.1 MB/s
# ...

# %%
pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 61.7 MB 1.1 MB/s
# ...

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 9.2 MB 12.9 MB/s
# ...
#      |████████████████████████████████| 301 kB 65.6 MB/s
# ...
#      |████████████████████████████████| 103 kB 67.6 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 59.9 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 54.4 MB/s
# ...

# %% [markdown]
# ## Race Classification

# %%
# !python /content/gdrive/MyDrive/image-race-clasification/pred.py --img_dir /content/gdrive/MyDrive/image-race-clasification/test_images --model /content/gdrive/MyDrive/image-race-clasification/face_model.pkl
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neural_network.multilayer_perceptron module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neural_network. Anything that cannot be imported from sklearn.neural_network is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.preprocessing.label module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.preprocessing. Anything that cannot be imported from sklearn.preprocessing is now part of the private API.
#   warnings.warn(message, FutureWarning)
# ...

# %% [markdown]
# ## Demo Image
# 0-> Asian, 1-> White 2-> Black

# %%
from PIL import Image
from glob import glob
paths = ["./results/*.jpg", "./results/*.png"]
for i in range(len(paths)):
    for image_path in glob(paths[i]):
      image = Image.open(image_path)
      display(image)
